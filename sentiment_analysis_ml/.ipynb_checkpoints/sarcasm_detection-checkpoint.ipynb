# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
try:
    # %tensorflow_version 2.x
except Exception:
    pass

# %%
import json
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
import datetime

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# sample code to show tokenization of sentences

# %%
sentences = [
    'i love my dog',
    'I, love my cat',
    'You love my dog!',#focus on how tokenizer didnt create a new word for dog!
    'do you think my dog is amazing?'# adding new words
    
]

tokenizer = Tokenizer(num_words = 100,oov_token = "<OOV>")# adding out of vocabulary to ensure we do not lose the len of sentence for the words it hasnt seen before

tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'you': 6, 'cat': 7, 'do': 8, 'think': 9, 'is': 10, 'amazing': 11}

# %%
sequences = tokenizer.texts_to_sequences(sentences)# simply shows texts interpreted as numbers generated by tokenizer
#simple tensor can not handle unequal length sentences
#teherfor we'll have to pad the sentences to ensure an equal length
#or USE RAGGED TENSOR
padded = pad_sequences(sequences,maxlen=5)#if len is more than this specify how to truncate i.e. pre or post
#padding can be done both pre and post by  usin padding ='post' or 'pre' default is pre
#also truncatin ='post' or 'pre' can be used default is pre with maxlen

print('\nWord_index =',word_index)
print("\nSequences =",sequences)
print("\nPadded Sequences:",padded)
# Out:
# Word_index = {'<OOV>': 1, 'my': 2, 'love': 3, 'dog': 4, 'i': 5, 'you': 6, 'cat': 7, 'do': 8, 'think': 9, 'is': 10, 'amazing': 11}
#
# Sequences = [[5, 3, 2, 4], [5, 3, 2, 7], [6, 3, 2, 4], [8, 6, 9, 2, 4, 10, 11]]
#
# Padded Sequences: [[ 0  5  3  2  4]
#  [ 0  5  3  2  7]
#  [ 0  6  3  2  4]
#  [ 9  2  4 10 11]]

# %%
test_data = [
    'i really love my dog',
    'my dog loves my mantee'
]
test_seq= tokenizer.texts_to_sequences(test_data)
padded_test_seq = pad_sequences(test_seq,maxlen=10)
print (padded_test_seq)
# Out:
# [[0 0 0 0 0 5 1 3 2 4]
#  [0 0 0 0 0 2 4 1 2 1]]

# %% [markdown]
# # Sentiment (sarcasm) analysis on news head lines

# %%
#importing data

# !wget --no-check-certificate\
   https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
   -O /tmp/sarcasm.json
# Out:
# --2020-03-28 01:38:51--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 2404:6800:4002:80d::2010, 172.217.160.144
# Connecting to storage.googleapis.com (storage.googleapis.com)|2404:6800:4002:80d::2010|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M   427KB/s    in 15s
#
# 2020-03-28 01:39:07 (370 KB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]

# %%
vocab_size =10000
embedding_dim = 16
max_length = 100
trunc_type = 'post'
padding_type='post'
oov_token = "<OOV>"
training_size = 20000

# %%
with open("/tmp/sarcasm.json",'r') as f:
    datastore = json.load(f)
    #simply opening json file and storing it in python list format
    
sentences =[]
labels =[]

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
d= {'sentences':sentences,'labels':labels}
df = pd.DataFrame(d)
 
df['labels'].value_counts()
df.head()
is_sarcastic = df[df['labels']==1]
not_sarcastic = df[df['labels']==0]
is_sarcastic.shape,not_sarcastic.shape

not_sarcastic= not_sarcastic.sample(is_sarcastic.shape[0])

df =is_sarcastic.append(not_sarcastic,ignore_index=True)
df =df.sample(frac=1).reset_index(drop=True)

#The frac keyword argument specifies the fraction of rows to return in the random sample, so frac=1 means return all rows (in random order).
#Here, specifying drop=True prevents .reset_index from creating a column containing the old index entries.

# %%
training_data = df[0:training_size]
testing_data = df[training_size:]

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token = oov_token)
#initailises tokeniser with vocab size and oov token
tokenizer.fit_on_texts(training_data['sentences'])

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_data['sentences'])
training_padded = pad_sequences(training_sequences, maxlen= max_length,padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_data['sentences'])
testing_padded = pad_sequences(testing_sequences, maxlen= max_length,padding=padding_type, truncating=trunc_type)

# %%
#need this block to get it to work with tensorflow 2.x

training_padded =np.array(training_padded)
testing_padded =np.array(testing_padded)
training_labels =np.array(training_data['labels'])
testing_labels =np.array(testing_data['labels'])

# %%
#model

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size,embedding_dim,input_length=max_length),
    #Turns positive integers (indexes) into dense vectors of fixed size. eg. [[4], [20]] -> [[0.25, 0.1], [0.6, -0.2]]
    #use some kind of mapping
    #https://keras.io/layers/embeddings/     for reference
    #Input shape : 2D tensor with shape: (batch_size, sequence_length).
    #Output shape : 3D tensor with shape: (batch_size, sequence_length, output_dim).
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')

])

model.compile(loss='binary_crossentropy',optimizer = 'adam',metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 100, 16)           160000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                408
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 160,433
# Trainable params: 160,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
path = "/home/deity/Documents/sentiment_analysis" + datetime.datetime.now().strftime()

# %%
num_epochs = 30
history = model.fit(training_padded,training_labels,epochs = num_epochs,
                   validation_data=(testing_padded,testing_labels),verbose =2)
# Out:
# Train on 20000 samples, validate on 3448 samples
# Epoch 1/30
# 20000/20000 - 2s - loss: 0.6576 - accuracy: 0.6436 - val_loss: 0.5376 - val_accuracy: 0.8170
# Epoch 2/30
# 20000/20000 - 1s - loss: 0.4108 - accuracy: 0.8406 - val_loss: 0.3861 - val_accuracy: 0.8231
# Epoch 3/30
# 20000/20000 - 1s - loss: 0.3063 - accuracy: 0.8775 - val_loss: 0.3490 - val_accuracy: 0.8521
# Epoch 4/30
# 20000/20000 - 1s - loss: 0.2580 - accuracy: 0.9002 - val_loss: 0.3406 - val_accuracy: 0.8530
# Epoch 5/30
# 20000/20000 - 1s - loss: 0.2234 - accuracy: 0.9136 - val_loss: 0.3420 - val_accuracy: 0.8547
# Epoch 6/30
# 20000/20000 - 1s - loss: 0.1968 - accuracy: 0.9260 - val_loss: 0.3540 - val_accuracy: 0.8527
# Epoch 7/30
# 20000/20000 - 1s - loss: 0.1747 - accuracy: 0.9369 - val_loss: 0.3669 - val_accuracy: 0.8509
# Epoch 8/30
# 20000/20000 - 1s - loss: 0.1569 - accuracy: 0.9420 - val_loss: 0.3781 - val_accuracy: 0.8501
# Epoch 9/30
# 20000/20000 - 1s - loss: 0.1394 - accuracy: 0.9514 - val_loss: 0.3979 - val_accuracy: 0.8472
# Epoch 10/30
# 20000/20000 - 1s - loss: 0.1262 - accuracy: 0.9560 - val_loss: 0.4272 - val_accuracy: 0.8385
# Epoch 11/30
# 20000/20000 - 1s - loss: 0.1149 - accuracy: 0.9605 - val_loss: 0.4470 - val_accuracy: 0.8408
# Epoch 12/30
# 20000/20000 - 1s - loss: 0.1042 - accuracy: 0.9646 - val_loss: 0.4721 - val_accuracy: 0.8382
# Epoch 13/30
# 20000/20000 - 2s - loss: 0.0954 - accuracy: 0.9678 - val_loss: 0.5036 - val_accuracy: 0.8303
# Epoch 14/30
# 20000/20000 - 1s - loss: 0.0873 - accuracy: 0.9707 - val_loss: 0.5528 - val_accuracy: 0.8202
# Epoch 15/30
# 20000/20000 - 1s - loss: 0.0811 - accuracy: 0.9730 - val_loss: 0.5614 - val_accuracy: 0.8315
# Epoch 16/30
# 20000/20000 - 2s - loss: 0.0744 - accuracy: 0.9751 - val_loss: 0.5982 - val_accuracy: 0.8228
# Epoch 17/30
# 20000/20000 - 1s - loss: 0.0670 - accuracy: 0.9789 - val_loss: 0.6275 - val_accuracy: 0.8225
# Epoch 18/30
# 20000/20000 - 1s - loss: 0.0637 - accuracy: 0.9801 - val_loss: 0.6515 - val_accuracy: 0.8260
# Epoch 19/30
# 20000/20000 - 1s - loss: 0.0565 - accuracy: 0.9827 - val_loss: 0.6922 - val_accuracy: 0.8231
# Epoch 20/30
# 20000/20000 - 1s - loss: 0.0530 - accuracy: 0.9834 - val_loss: 0.7249 - val_accuracy: 0.8269
# Epoch 21/30
# 20000/20000 - 1s - loss: 0.0498 - accuracy: 0.9840 - val_loss: 0.7635 - val_accuracy: 0.8213
# Epoch 22/30
# 20000/20000 - 1s - loss: 0.0460 - accuracy: 0.9865 - val_loss: 0.8200 - val_accuracy: 0.8141
# Epoch 23/30
# 20000/20000 - 1s - loss: 0.0431 - accuracy: 0.9861 - val_loss: 0.8500 - val_accuracy: 0.8132
# Epoch 24/30
# 20000/20000 - 1s - loss: 0.0389 - accuracy: 0.9883 - val_loss: 0.8610 - val_accuracy: 0.8184
# Epoch 25/30
# 20000/20000 - 1s - loss: 0.0358 - accuracy: 0.9891 - val_loss: 0.8991 - val_accuracy: 0.8167
# Epoch 26/30
# 20000/20000 - 1s - loss: 0.0342 - accuracy: 0.9898 - val_loss: 0.9378 - val_accuracy: 0.8135
# Epoch 27/30
# 20000/20000 - 1s - loss: 0.0322 - accuracy: 0.9904 - val_loss: 0.9680 - val_accuracy: 0.8126
# Epoch 28/30
# 20000/20000 - 1s - loss: 0.0273 - accuracy: 0.9923 - val_loss: 1.0169 - val_accuracy: 0.8153
# Epoch 29/30
# 20000/20000 - 1s - loss: 0.0273 - accuracy: 0.9919 - val_loss: 1.0485 - val_accuracy: 0.8115
# Epoch 30/30
# 20000/20000 - 1s - loss: 0.0256 - accuracy: 0.9927 - val_loss: 1.1245 - val_accuracy: 0.8129

# %%
def plot_graphs(history,string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("epochs")
    plt.ylabel(string)
    plt.legend([string,'val_'+string])
    plt.show()
    
plot_graphs(history,"accuracy")
plot_graphs(history,"loss")

# %%
reverse_word_index = dict([(value,key) for (key,value) in word_index.items()])

def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i,'?') for i in text])

print(decode_sentence(training_padded[2]))
print(df['sentences'][2])
print(df['labels'][2])
# Out:
# nation's <OOV> enter last stage of prep for thursday's thanksgiving debates ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# nation's uncles enter last stage of prep for thursday's thanksgiving debates
# 1

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) 
#shape : (vocab_size, embedding_dim)
# Out:
# (10000, 16)

# %%
sentence = ["granny starting to fear spiders in the garden might be real", "game of thrones season finale showing this sunday night"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# [[0.9997942 ]
#  [0.37651202]]
